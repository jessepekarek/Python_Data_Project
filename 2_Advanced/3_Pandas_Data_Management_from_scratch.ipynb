# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#             job_title_short  \
# 458130         Data Analyst
# 541432        Data Engineer
# 450560       Data Scientist
# 26658         Data Engineer
# 564997  Senior Data Analyst
# 725656       Data Scientist
# 476552         Data Analyst
# 533466       Data Scientist
# 741924        Data Engineer
# 31256   Senior Data Analyst
#
#                                                 job_title  \
# 458130                                       Data Analyst
# 541432                               Data Center Engineer
# 450560                                  Sr Data Scientist
# 26658   Capitec Bank Vacancies for 2022 – Data Engineer I
# 564997                                Senior Data Analyst
# 725656                                     Data Scientist
# 476552                                       Data Analyst
# 533466                           Marketing Data Scientist
# 741924                                      Data Engineer
# 31256                                 Senior Data Analyst
#
#                    job_location              job_via job_schedule_type  \
# 458130                Singapore  via BeBee Singapore         Full-time
# 541432              Switzerland    via BeBee Schweiz         Full-time
# 450560              Fremont, CA    via Simplify Jobs         Full-time
# 26658   Cape Town, South Africa     via VacanciesHut         Full-time
# 564997              Afghanistan      via Trabajo.org         Full-time
# 725656        Las Condes, Chile      via BeBee Chile         Full-time
# 476552               Austin, TX     via ZipRecruiter         Full-time
# 533466           Cheltenham, UK            via BeBee         Full-time
# 741924                   Canada      via Trabajo.org         Full-time
# 31256             Edinburgh, UK        via Totaljobs         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 458130               False                  Singapore 2023-12-08 14:32:35
# 541432               False                Switzerland 2023-02-22 19:49:04
# 450560               False  California, United States 2023-01-03 23:32:37
# 26658                False               South Africa 2023-01-01 14:08:56
# 564997               False                Afghanistan 2023-07-06 05:14:53
# 725656               False                      Chile 2023-02-03 21:52:18
# 476552               False       Texas, United States 2023-04-11 14:01:19
# 533466               False             United Kingdom 2023-12-25 19:23:41
# 741924               False                     Canada 2023-03-14 20:27:54
# 31256                False             United Kingdom 2023-08-31 13:44:10
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 458130                   True                 False       Singapore
# 541432                   True                 False     Switzerland
# 450560                  False                  True   United States
# 26658                   False                 False    South Africa
# 564997                   True                 False     Afghanistan
# 725656                  False                 False           Chile
# 476552                   True                 False   United States
# 533466                  False                 False  United Kingdom
# 741924                   True                 False          Canada
# 31256                    True                 False  United Kingdom
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 458130        None              NaN              NaN
# 541432        None              NaN              NaN
# 450560        None              NaN              NaN
# 26658         None              NaN              NaN
# 564997        None              NaN              NaN
# 725656        None              NaN              NaN
# 476552        None              NaN              NaN
# 533466        None              NaN              NaN
# 741924        None              NaN              NaN
# 31256         None              NaN              NaN
#
#                       company_name  \
# 458130  Good Job Creations Pte Ltd
# 541432         Reboot Monkeys B.V.
# 450560                       Weee!
# 26658                 Capitec Bank
# 564997                       Amway
# 725656                     Equifax
# 476552                 Atolla Tech
# 533466                      Ripjar
# 741924                Carol Stream
# 31256               Hamilton Forth
#
#                                                job_skills  \
# 458130                     ['java', 'python', 'sql', 'r']
# 541432                                    ['go', 'linux']
# 450560                       ['sql', 'python', 'tableau']
# 26658     ['aws', 'redshift', 'word', 'excel', 'outlook']
# 564997                                               None
# 725656                      ['python', 'sql', 'bigquery']
# 476552                               ['matlab', 'python']
# 533466  ['python', 'pytorch', 'scikit-learn', 'numpy',...
# 741924                                               None
# 31256        ['sql', 'python', 'tableau', 'qlik', 'flow']
#
#                                           job_type_skills
# 458130    {'programming': ['java', 'python', 'sql', 'r']}
# 541432           {'os': ['linux'], 'programming': ['go']}
# 450560  {'analyst_tools': ['tableau'], 'programming': ...
# 26658   {'analyst_tools': ['word', 'excel', 'outlook']...
# 564997                                               None
# 725656  {'cloud': ['bigquery'], 'programming': ['pytho...
# 476552              {'programming': ['matlab', 'python']}
# 533466  {'libraries': ['pytorch', 'scikit-learn', 'num...
# 741924                                               None
# 31256   {'analyst_tools': ['tableau', 'qlik'], 'other'...

# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

df_copy = df.copy()
df_cleaned = df_copy.dropna(subset=['salary_year_avg'])
df_cleaned.head(5)
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# 92          Full-time                True    Illinois, United States
# 100         Full-time               False  California, United States
# 109         Full-time                True    Illinois, United States
#
#         job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28  2023-08-01 13:37:57                  False                 False
# 77  2023-06-26 14:22:54                  False                 False
# 92  2023-02-21 13:29:59                  False                  True
# 100 2023-07-31 13:01:18                  False                  True
# 109 2023-10-12 13:02:19                  False                  True
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28      Costa Rica        year         109500.0              NaN
# 77           Sudan        year         140000.0              NaN
# 92   United States        year         120000.0              NaN
# 100  United States        year         228222.0              NaN
# 109  United States        year          89000.0              NaN
#
#                         company_name  \
# 28                          Netskope
# 77                        Intelletec
# 92                      Apex Systems
# 100                           TikTok
# 109  Get It Recruit - Transportation
#
#                                             job_skills  \
# 28                                   ['gdpr', 'excel']
# 77   ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                   ['sql', 'python']
# 100                  ['sql', 'r', 'python', 'express']
# 109              ['python', 'r', 'alteryx', 'tableau']
#
#                                        job_type_skills
# 28   {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77   {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                  {'programming': ['sql', 'python']}
# 100  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %%
df_sample = df.sample(frac=0.1)
df_sample.head(5)
# Out:
#              job_title_short                                job_title  \
# 240170          Data Analyst            Manager, Data (Ads Data Team)
# 683118          Data Analyst         Data Analyst (m/w/d) | Frankfurt
# 11306         Data Scientist     Consultant, Data Science & Analytics
# 388229        Data Scientist  Research Student, Ph.D. in Data Science
# 371675  Senior Data Engineer                Senior Lead Data Engineer
#
#                     job_location                    job_via job_schedule_type  \
# 240170                    Poland  via Smart Recruiters Jobs         Full-time
# 683118        Frankfurt, Germany                   via XING         Full-time
# 11306   Pune, Maharashtra, India                 via Jooble         Full-time
# 388229          Skoghall, Sweden               via LinkedIn         Full-time
# 371675          Philadelphia, PA             via KHON2 Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 240170               False                  Poland 2023-12-07 07:35:18
# 683118               False                 Germany 2023-11-03 10:12:40
# 11306                False                   India 2023-08-24 13:29:44
# 388229               False                  Sweden 2023-04-05 18:12:12
# 371675               False  Florida, United States 2023-06-12 18:29:01
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 240170                   True                 False         Poland
# 683118                   True                 False        Germany
# 11306                   False                 False          India
# 388229                  False                 False         Sweden
# 371675                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  company_name  \
# 240170        None              NaN              NaN       Allegro
# 683118        None              NaN              NaN  ADVERGY GmbH
# 11306         None              NaN              NaN    TransUnion
# 388229        None              NaN              NaN    Stora Enso
# 371675        year         246500.0              NaN   Capital One
#
#                                                job_skills  \
# 240170                                 ['sql', 'windows']
# 683118                                               None
# 11306                        ['r', 'sas', 'sas', 'spark']
# 388229                                               None
# 371675  ['java', 'scala', 'python', 'nosql', 'sql', 'm...
#
#                                           job_type_skills
# 240170        {'os': ['windows'], 'programming': ['sql']}
# 683118                                               None
# 11306   {'analyst_tools': ['sas'], 'libraries': ['spar...
# 388229                                               None
# 371675  {'cloud': ['redshift', 'snowflake', 'aws', 'az...

# %%
median_salary_year = df['salary_year_avg'].median()
median_salary_year
# Out:
# 115000.0

# %%
df_copy = df.copy()
df_copy['salary_year_avg'] = df_copy['salary_year_avg'].fillna(median_salary_year)
df_copy.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0         115000.0              NaN          Boehringer Ingelheim
# 1         115000.0              NaN    Hewlett Packard Enterprise
# 2         115000.0              NaN      ALPHA Augmented Services
# 3         115000.0              NaN  Southwest Research Institute
# 4         115000.0              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
